# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Indian_cities.csv")

# %%
df.shape
# Out:
# (493, 22)

# %%
df.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name_of_city                    493 non-null    object
#  1   state_code                      493 non-null    int64
#  2   state_name                      493 non-null    object
#  3   dist_code                       493 non-null    int64
#  4   population_total                493 non-null    int64
#  5   population_male                 493 non-null    int64
#  6   population_female               493 non-null    int64
#  7   0-6_population_total            493 non-null    int64
#  8   0-6_population_male             493 non-null    int64
#  9   0-6_population_female           493 non-null    int64
#  10  literates_total                 493 non-null    int64
#  11  literates_male                  493 non-null    int64
# ...

# %%
number = df.select_dtypes(np.number)
number.columns
# Out:
# Index(['state_code', 'dist_code', 'population_total', 'population_male',
#        'population_female', '0-6_population_total', '0-6_population_male',
#        '0-6_population_female', 'literates_total', 'literates_male',
#        'literates_female', 'sex_ratio', 'child_sex_ratio',
#        'effective_literacy_rate_total', 'effective_literacy_rate_male',
#        'effective_literacy_rate_female', 'total_graduates', 'male_graduates',
#        'female_graduates'],
#       dtype='object')

# %%
df[['state_code', 'dist_code', 'population_total', 'population_male',
       'population_female', '0-6_population_total', '0-6_population_male',
       '0-6_population_female', 'literates_total', 'literates_male',
       'literates_female', 'sex_ratio', 'child_sex_ratio',
       'effective_literacy_rate_total', 'effective_literacy_rate_male',
       'effective_literacy_rate_female', 'total_graduates', 'male_graduates',
       'female_graduates']] = df[['state_code', 'dist_code', 'population_total', 'population_male',
       'population_female', '0-6_population_total', '0-6_population_male',
       '0-6_population_female', 'literates_total', 'literates_male',
       'literates_female', 'sex_ratio', 'child_sex_ratio',
       'effective_literacy_rate_total', 'effective_literacy_rate_male',
       'effective_literacy_rate_female', 'total_graduates', 'male_graduates',
       'female_graduates']].astype(int)

# %%
df.describe().T
# Out:
#                                 count           mean           std       min  \
# state_code                      493.0      18.643002  9.297168e+00       1.0
# dist_code                       493.0      16.782961  1.556613e+01       1.0
# population_total                493.0  448112.373225  1.033228e+06  100036.0
# population_male                 493.0  234346.789047  5.487786e+05   50201.0
# population_female               493.0  213765.584178  4.848622e+05   45126.0
# 0-6_population_total            493.0   47092.847870  1.050279e+05    6547.0
# 0-6_population_male             493.0   24849.527383  5.553531e+04    3406.0
# 0-6_population_female           493.0   22243.320487  4.952324e+04    3107.0
# literates_total                 493.0  346152.728195  8.220952e+05   56998.0
# literates_male                  493.0  189438.440162  4.534753e+05   34751.0
# literates_female                493.0  156714.288032  3.690677e+05   22247.0
# ...

# %% [markdown]
# # Top 5 higest & lowest Populated State:-

# %%
top_5 = df.groupby(['state_name'],as_index = False)['population_total'].sum().sort_values(by = 'population_total', ascending = False).head()
sns.set(rc = {'figure.figsize':(10,5)})
x = sns.barplot(data = top_5, x = 'state_name', y = 'population_total', hue = 'population_total',palette = 'rainbow', legend = False)
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 higest populated States", color = "red", size = 20)
plt.xlabel("States Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.grid(False)
plt.show()

# %%
tail_5 = df.groupby(['state_name'],as_index = False)['population_total'].sum().sort_values(by = 'population_total', ascending = False).tail()
sns.set(rc = {'figure.figsize':(10,5)})
x = sns.barplot(data = top_5, x = 'state_name', y = 'population_total', hue = 'population_total',palette = 'bright', legend = False)
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 lowest populated States", color = "red", size = 20)
plt.xlabel("States Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.xticks(rotation = 15)
plt.grid(False)
plt.show()

# %% [markdown]
# # In above both graph we find that "Maharashtra" has higest population and "Andaman & Nicobar" has lowest population.

# %% [markdown]
# # Top 5 higest & lowest populated city:-

# %%
top_5sch=df.groupby(['state_name','name_of_city'], as_index = False)['population_total'].max().sort_values(by = 'population_total', ascending = False).head()
sns.set(rc = {'figure.figsize':(10,5)})
x = sns.barplot(data = top_5sch, x = 'name_of_city', y = 'population_total', hue = 'state_name',palette = 'bright')
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 highest populated Cities", color = "red", size = 20)
plt.xlabel("Cities Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.xticks(rotation = 15)
plt.grid(False)
plt.show()

# %%
top_5scl=df.groupby(['state_name','name_of_city'], as_index = False)['population_total'].max().sort_values(by = 'population_total', ascending = False).tail()
x = sns.barplot(data = top_5scl, x = 'name_of_city', y = 'population_total', hue = 'state_name',palette = 'bright')
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 lowest populated Cities", color = "red", size = 20)
plt.xlabel("Cities Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.xticks(rotation = 15)
plt.legend(loc = 'best',bbox_to_anchor = (1,1))
plt.grid(False)
plt.show()

# %% [markdown]
# # According to above last two graphs we find out that "Greater Mumbai" from state "Maharashtra" has higest Population & "Nagada" from "Rajasthan" has lowest Population.

# %% [markdown]
# # Top 5 higest Gender by Populated State :-

# %%
top_5smp = df.groupby('state_name', as_index = False)["population_male"].sum().sort_values(by = "population_male", ascending = False).head()
sns.set(rc = {'figure.figsize':(10,5)})
x = sns.barplot(data = top_5smp, x = 'state_name', y = 'population_male', hue = 'population_male',palette = 'rainbow', legend = False)
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 higest Male Populated States", color = "red", size = 20)
plt.xlabel("States Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.grid(False)
plt.show()

# %%
top_5sfp = df.groupby('state_name', as_index = False)["population_female"].sum().sort_values(by = "population_female", ascending = False).head()
sns.set(rc = {'figure.figsize':(10,5)})
x = sns.barplot(data = top_5sfp, x = 'state_name', y = 'population_female', hue = 'population_female',palette = 'rainbow', legend = False)
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 higest Female Populated States", color = "red", size = 20)
plt.xlabel("States Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.grid(False)
plt.show()

# %%
top_5smpl = df.groupby('state_name', as_index = False)["population_male"].sum().sort_values(by = "population_male", ascending = False).tail()
sns.set(rc = {'figure.figsize':(10,5)})
x = sns.barplot(data = top_5smpl, x = 'state_name', y = 'population_male', hue = 'population_male',palette = 'rainbow', legend = False)
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 lowest Male Populated States", color = "red", size = 20)
plt.xlabel("States Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.xticks(rotation = 15)
plt.grid(False)
plt.show()

# %%
top_5sfpl = df.groupby('state_name', as_index = False)["population_female"].sum().sort_values(by = "population_female", ascending = False).tail()
sns.set(rc = {'figure.figsize':(10,5)})
x = sns.barplot(data = top_5sfpl, x = 'state_name', y = 'population_female', hue = 'population_female',palette = 'rainbow', legend = False)
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 lowest Female Populated States", color = "red", size = 20)
plt.xlabel("States Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.xticks(rotation = 15)
plt.grid(False)
plt.show()

# %% [markdown]
# # According to above graph "Maharashtra" has highest "Male & Female" than other states and "Andaman & Nicobar" has lowest "Male & Female" Population.

# %% [markdown]
# # Top 5 higest 'Gender' by state & city :-

# %%
top_5scm = df.groupby(["state_name",'name_of_city'], as_index = False)["population_male"].max().sort_values(by = "population_male", ascending = False).head()
sns.set(rc = {'figure.figsize':(10,5)})
x = sns.barplot(data = top_5scm, x = 'name_of_city', y = 'population_male', hue = 'state_name',palette = 'rainbow')
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 lowest Male Populated States", color = "red", size = 20)
plt.xlabel("States Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.xticks(rotation = 15)
plt.grid(False)
plt.show()

# %%
top_5scf = df.groupby(["state_name",'name_of_city'], as_index = False)["population_female"].max().sort_values(by = "population_female", ascending = False).head()
sns.set(rc = {'figure.figsize':(10,5)})
x = sns.barplot(data = top_5scf, x = 'name_of_city', y = 'population_female', hue = 'state_name',palette = 'rainbow')
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 lowest Female Populated States", color = "red", size = 20)
plt.xlabel("States Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.xticks(rotation = 15)
plt.grid(False)
plt.show()

# %% [markdown]
# # In above two graph we get "Greater Mumbai" from "Maharashtra" has higest "Male & Female" population.

# %% [markdown]
# # Top 5 lowest Gender by City :-

# %%
top_5scml = df.groupby(["state_name",'name_of_city'], as_index = False)["population_male"].max().sort_values(by = "population_male", ascending = False).tail()
sns.set(rc = {'figure.figsize':(10,5)})
x = sns.barplot(data = top_5scml, x = 'name_of_city', y = 'population_male', hue = 'state_name',palette = 'rainbow')
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 lowest Male Populated Cities", color = "red", size = 20)
plt.xlabel("Cities Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.legend(loc = "best", bbox_to_anchor = (1,1))
plt.xticks(rotation = 15)
plt.grid(False)
plt.show()

# %%
top_5scml = df.groupby(["state_name",'name_of_city'], as_index = False)["population_female"].max().sort_values(by = "population_female", ascending = False).tail()
sns.set(rc = {'figure.figsize':(10,5)})
x = sns.barplot(data = top_5scml, x = 'name_of_city', y = 'population_female', hue = 'state_name',palette = 'rainbow')
for bar in x.containers:
    x.bar_label(bar)
plt.title("Top 5 lowest Female Populated Cities", color = "red", size = 20)
plt.xlabel("Cities Name", color = "red", size = 15)
plt.ylabel("Population", color = "red", size = 15)
plt.legend(loc = "best", bbox_to_anchor = (1,1))
plt.xticks(rotation = 15)
plt.grid(False)
plt.show()

# %% [markdown]
# # According to above last two graph we find that "Chilakaluripet" from 'Tamil Nadu' has lowest 'Male' population city and "Bhiwadi" from 'Rajasthan' has lowest 'Female' Population city.

# %%
top_5lcs = df.groupby(['state_name','name_of_city'],as_index = False)['literates_total'].max().sort_values(by = "literates_total", ascending = False).head()
x = sns.barplot(data = top_5lcs, x = 'name_of_city', y = 'literates_total',hue = 'state_name',palette = 'Set3')
for bar in x.containers:
    x.bar_label(bar)
plt.title("Total Literates by City", color = "green", size = 20)
plt.xlabel("State",color = "green", size = 15)
plt.ylabel("Literates Counts", color = "green", size = 15)
plt.grid(False)
plt.show()

# %%
top_5lcsm = df.groupby(['state_name','name_of_city'],as_index = False)['literates_male'].max().sort_values(by = "literates_male", ascending = False).head()
x = sns.barplot(data = top_5lcsm, x = 'name_of_city', y = 'literates_male',hue = 'state_name',palette = 'Set3')
for bar in x.containers:
    x.bar_label(bar)
plt.title("Total Male Literates by City", color = "green", size = 20)
plt.xlabel("State",color = "green", size = 15)
plt.ylabel("Male Literates Counts", color = "green", size = 15)
plt.grid(False)
plt.show()

# %%
top_5lcsf = df.groupby(['state_name','name_of_city'],as_index = False)['literates_female'].max().sort_values(by = "literates_female", ascending = False).head()
x = sns.barplot(data = top_5lcsf, x = 'name_of_city', y = 'literates_female',hue = 'state_name',palette = 'Set3')
for bar in x.containers:
    x.bar_label(bar)
plt.title("Total Female Literates by City", color = "green", size = 20)
plt.xlabel("State",color = "green", size = 15)
plt.ylabel("Female Literates Counts", color = "green", size = 15)
plt.grid(False)
plt.show()

# %% [markdown]
# # According to above three graph "Greater Mumbai" from "Maharashtra" has higest "Leterates" Population.

# %% [markdown]
# # Sex_Ratio:-

# %%
top_5s = df.groupby(['state_name'],as_index = False)['sex_ratio'].sum().sort_values(by = "sex_ratio", ascending = False).head()
x = sns.barplot(data = top_5s, x = "state_name", y = "sex_ratio", hue = 'state_name', palette = "Set2")
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 States Sex Ratio",color = "Yellow", size = 20)
plt.xlabel("States Name",color = "Yellow", size = 15)
plt.ylabel("Total Ratio",color = "Yellow", size = 15)
plt.grid(False)
plt.show()

# %%
top_5sr = df.groupby(['state_name','name_of_city'],as_index = False)['sex_ratio'].max().sort_values(by = "sex_ratio", ascending = False).head()
x = sns.barplot(data = top_5sr, x = "name_of_city", y = "sex_ratio", hue = 'state_name', palette = "Set2")
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 Cities Sex Ratio",color = "Yellow", size = 20)
plt.xlabel("Cities Name",color = "Yellow", size = 15)
plt.ylabel("Total Ratio",color = "Yellow", size = 15)
plt.legend(loc = "best", bbox_to_anchor = (1,1))
plt.grid(False)
plt.show()

# %% [markdown]
# # Above two chart "West Bengal" has higest 'Sex Ratio' but top 5 cities of " Kerala" has higest "Sex Ratio".

# %% [markdown]
# # Child Sex Ratio :-

# %%
top_5csrs = df.groupby(['state_name'],as_index = False)['child_sex_ratio'].sum().sort_values(by = 'child_sex_ratio', ascending = False).head()
x = sns.barplot(data = top_5csrs, x = 'state_name', y = 'child_sex_ratio', hue = 'state_name', palette = 'Set2')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 State by Child Sex Ratio", color = 'red', size = 20)
plt.xlabel("State Name", color = 'red', size = 15)
plt.ylabel("Ratio", color = 'red', size = 15)
plt.grid(False)
plt.show()

# %%
top_5csrsc = df.groupby(['state_name','name_of_city'],as_index = False)['child_sex_ratio'].max().sort_values(by = 'child_sex_ratio', ascending = False).head()
x = sns.barplot(data = top_5csrsc, x = 'name_of_city', y = 'child_sex_ratio', hue = 'state_name', palette = 'Set2')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 Cities by Child Sex Ratio", color = 'red', size = 20)
plt.xlabel("City Name", color = 'red', size = 15)
plt.ylabel("Ratio", color = 'red', size = 15)
plt.legend(loc = "best", bbox_to_anchor = (1,1))
plt.grid(False)
plt.show()

# %% [markdown]
# # Accordind to above both graph "West Bengal" and "Bally" which is city of "West Bengal" has higest "Child Sex Ratio".

# %% [markdown]
# # Effective Literacy Rate :-

# %%
top_5elr = df.groupby(['state_name'],as_index = False)['effective_literacy_rate_total'].sum().sort_values(by = 'effective_literacy_rate_total', ascending = False).head()
x = sns.barplot(data = top_5elr, x = 'state_name', y = 'effective_literacy_rate_total', hue = 'state_name', palette = 'Set2')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 State by Effective Literacy Rate", color = 'red', size = 20)
plt.xlabel("State Name", color = 'red', size = 15)
plt.ylabel("Literacy Rate", color = 'red', size = 15)
plt.grid(False)
plt.show()

# %%
top_5elrm = df.groupby(['state_name'],as_index = False)['effective_literacy_rate_male'].sum().sort_values(by = 'effective_literacy_rate_male', ascending = False).head()
x = sns.barplot(data = top_5elrm, x = 'state_name', y = 'effective_literacy_rate_male', hue = 'state_name', palette = 'Set2')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 State by Effective Literacy Rate Male", color = 'red', size = 20)
plt.xlabel("State Name", color = 'red', size = 15)
plt.ylabel("Literacy Rate", color = 'red', size = 15)
plt.grid(False)
plt.show()

# %%
top_5elrf = df.groupby(['state_name'],as_index = False)['effective_literacy_rate_female'].sum().sort_values(by = 'effective_literacy_rate_female', ascending = False).head()
x = sns.barplot(data = top_5elrf, x = 'state_name', y = 'effective_literacy_rate_female', hue = 'state_name', palette = 'Set2')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 State by Effective Literacy Rate Female", color = 'red', size = 20)
plt.xlabel("State Name", color = 'red', size = 15)
plt.ylabel("Literacy Rate", color = 'red', size = 15)
plt.grid(False)
plt.show()

# %% [markdown]
# # According to above three graph "West Bengal" has higest 'Effective Literacy Rate'.

# %% [markdown]
# # Top 5 cities by effective literacy rate :-

# %%
top_5elrc = df.groupby(['state_name','name_of_city'],as_index = False)['effective_literacy_rate_total'].max().sort_values(by = 'effective_literacy_rate_total', ascending = False).head()
x = sns.barplot(data = top_5elrc, x = 'name_of_city', y = 'effective_literacy_rate_total', hue = 'state_name', palette = 'Set2')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 city by Effective Literacy Rate", color = 'red', size = 20)
plt.xlabel("City Name", color = 'red', size = 15)
plt.ylabel("Literacy Rate", color = 'red', size = 15)
plt.legend(loc = "best", bbox_to_anchor = (1,1))
plt.grid(False)
plt.show()

# %%
top_5elrcm = df.groupby(['state_name','name_of_city'],as_index = False)['effective_literacy_rate_male'].max().sort_values(by = 'effective_literacy_rate_male', ascending = False).head()
x = sns.barplot(data = top_5elrcm, x = 'name_of_city', y = 'effective_literacy_rate_male', hue = 'state_name', palette = 'Set2')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 city by Effective Literacy Rate Male", color = 'red', size = 20)
plt.xlabel("City Name", color = 'red', size = 15)
plt.ylabel("Literacy Rate", color = 'red', size = 15)
plt.legend(loc = "best", bbox_to_anchor = (1,1))
plt.grid(False)
plt.show()

# %%
top_5elrcm = df.groupby(['state_name','name_of_city'],as_index = False)['effective_literacy_rate_female'].max().sort_values(by = 'effective_literacy_rate_female', ascending = False).head()
x = sns.barplot(data = top_5elrcm, x = 'name_of_city', y = 'effective_literacy_rate_female', hue = 'state_name', palette = 'Set2')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 city by Effective Literacy Rate Female", color = 'red', size = 20)
plt.xlabel("City Name", color = 'red', size = 15)
plt.ylabel("Literacy Rate", color = 'red', size = 15)
plt.legend(loc = "best", bbox_to_anchor = (1,1))
plt.grid(False)
plt.show()

# %% [markdown]
# # Above three graphs we get that "Aizawl" city from "Mizoram" has higest 'Effective Literacy Rate'.

# %% [markdown]
# # State by Graduates :-

# %%
top_5sg = df.groupby(['state_name'],as_index = False)['total_graduates'].sum().sort_values(by = 'total_graduates', ascending = False).head()
x = sns.barplot(data = top_5sg, x = 'state_name', y = 'total_graduates', hue = 'state_name', palette = 'Set2')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 State by Graduates", color = 'red', size = 20)
plt.xlabel("State Name", color = 'red', size = 15)
plt.ylabel("Graduates Counts", color = 'red', size = 15)
plt.grid(False)
plt.show()

# %%
top_5gm = df.groupby(['state_name'],as_index = False)['male_graduates'].sum().sort_values(by = 'male_graduates', ascending = False).head()
x = sns.barplot(data = top_5gm, x = 'state_name', y = 'male_graduates', hue = 'state_name', palette = 'Set2')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 State by Male Graduates", color = 'red', size = 20)
plt.xlabel("State Name", color = 'red', size = 15)
plt.ylabel("Male Graduates", color = 'red', size = 15)
plt.grid(False)
plt.show()

# %%
top_5gf = df.groupby(['state_name'],as_index = False)['female_graduates'].sum().sort_values(by = 'female_graduates', ascending = False).head()
x = sns.barplot(data = top_5gf, x = 'state_name', y = 'female_graduates', hue = 'state_name', palette = 'Set2')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 State by Female Graduates", color = 'red', size = 20)
plt.xlabel("State Name", color = 'red', size = 15)
plt.ylabel("Female Graduates", color = 'red', size = 15)
plt.grid(False)
plt.show()

# %% [markdown]
# # Above three graps we understand that "Maharashtra" has higest "Graduate" Population.

# %% [markdown]
# # Top 5 higest City by Graduates :-

# %%
top_5gsc = df.groupby(['state_name','name_of_city'],as_index = False)['total_graduates'].max().sort_values(by = 'total_graduates', ascending = False).head()
x = sns.barplot(data = top_5gsc, x = 'name_of_city', y = 'total_graduates', hue = 'state_name', palette = 'Set1')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 State by Graduates", color = 'red', size = 20)
plt.xlabel("State Name", color = 'red', size = 15)
plt.ylabel("Total Graduates", color = 'red', size = 15)
plt.grid(False)
plt.show()

# %%
top_5gmsc = df.groupby(['state_name','name_of_city'],as_index = False)['male_graduates'].max().sort_values(by = 'male_graduates', ascending = False).head()
x = sns.barplot(data = top_5gmsc, x = 'name_of_city', y = 'male_graduates', hue = 'state_name', palette = 'Set1')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 State by Male Graduates", color = 'red', size = 20)
plt.xlabel("State Name", color = 'red', size = 15)
plt.ylabel("Male Graduates", color = 'red', size = 15)
plt.grid(False)
plt.show()

# %%
top_5gfsc = df.groupby(['state_name','name_of_city'],as_index = False)['female_graduates'].max().sort_values(by = 'female_graduates', ascending = False).head()
x = sns.barplot(data = top_5gfsc, x = 'name_of_city', y = 'female_graduates', hue = 'state_name', palette = 'Set1')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 State by Female Graduates", color = 'red', size = 20)
plt.xlabel("State Name", color = 'red', size = 15)
plt.ylabel("Female Graduates", color = 'red', size = 15)
plt.grid(False)
plt.show()

# %% [markdown]
# # According to above three graphs "Delhi" city from "NCT OF DELHI" has higest "Graduates".

# %%
top_5gscl = df.groupby(['state_name','name_of_city'],as_index = False)['total_graduates'].max().sort_values(by = 'total_graduates', ascending = False).tail()
x = sns.barplot(data = top_5gscl, x = 'name_of_city', y = 'total_graduates', hue = 'state_name', palette = 'Set1')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 City by Lowest Graduates", color = 'red', size = 20)
plt.xlabel("City Name", color = 'red', size = 15)
plt.ylabel("Total Graduates", color = 'red', size = 15)
plt.legend(loc = "best", bbox_to_anchor = (1,1))
plt.grid(False)
plt.show()

# %%
top_5gsclm = df.groupby(['state_name','name_of_city'],as_index = False)['male_graduates'].max().sort_values(by = 'male_graduates', ascending = False).tail()
x = sns.barplot(data = top_5gsclm, x = 'name_of_city', y = 'male_graduates', hue = 'state_name', palette = 'Set1')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 City by Lowest Male Graduates", color = 'red', size = 20)
plt.xlabel("Male Name", color = 'red', size = 15)
plt.ylabel("Graduates", color = 'red', size = 15)
plt.legend(loc = "best", bbox_to_anchor = (1,1))
plt.grid(False)
plt.show()

# %%
top_5gsclf = df.groupby(['state_name','name_of_city'],as_index = False)['female_graduates'].max().sort_values(by = 'female_graduates', ascending = False).tail()
x = sns.barplot(data = top_5gsclf, x = 'name_of_city', y = 'female_graduates', hue = 'state_name', palette = 'Set1')
for i in x.containers:
    x.bar_label(i)
plt.title("Top 5 City by Lowest Female Graduates", color = 'red', size = 20)
plt.xlabel("City Name", color = 'red', size = 15)
plt.ylabel("Graduates", color = 'red', size = 15)
plt.legend(loc = "best", bbox_to_anchor = (1,1))
plt.grid(False)
plt.show()

# %% [markdown]
# # According to above graphs "Dabgram" city from "West Bengal" has lowest 'Graduates'.
